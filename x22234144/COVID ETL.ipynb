# %%
import pandas as pd
from pymongo import MongoClient

# MongoDB connection parameters
mongo_uri = 'mongodb+srv://smulani239:Arif2212$@databaseprogramming.eavdhnn.mongodb.net/'  # Replace with your MongoDB URI
database_name = 'Database'
collection_name = 'COVID'

# Connect to MongoDB
client = MongoClient(mongo_uri)
db = client[database_name]
collection = db[collection_name]

# Fetch data from MongoDB collection
cursor = collection.find({})

# Convert MongoDB cursor to DataFrame
df = pd.DataFrame(list(cursor))

# Close the MongoDB connection
client.close()

df = df.drop('_id', axis=1)
# Display the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[1], line 18
#      15 cursor = collection.find({})
#      17 # Convert MongoDB cursor to DataFrame
# ---> 18 df = pd.DataFrame(list(cursor))
#      20 # Close the MongoDB connection
#      21 client.close()
#
# File C:\Python\lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File C:\Python\lib\site-packages\pymongo\cursor.py:1155, in Cursor._refresh(self)
#    1152     return len(self.__data)
#    1154 if not self.__session:
# -> 1155     self.__session = self.__collection.database.client._ensure_session()
#    1157 if self.__id is None:  # Query
#    1158     if (self.__min or self.__max) and not self.__hint:
#
# ...

# %%
import pandas as pd

df = pd.read_csv('covid.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Name of State / UT', 'Latitude', 'Longitude',
#        'Total Confirmed cases', 'Death', 'Cured/Discharged/Migrated',
#        'New cases', 'New deaths', 'New recovered', 'total_tests',
#        'total_recovered', 'active_cases'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame df with the specified columns
# Example DataFrame:
# df = ...

# Graph 1: Line plot for Total Confirmed cases over time
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Total Confirmed cases'])
plt.title('Total Confirmed cases over time')
plt.xlabel('Date')
plt.ylabel('Total Confirmed cases')
plt.show()

# Graph 2: Bar plot for Total Confirmed cases by State/UT
plt.figure(figsize=(12, 8))
sns.barplot(x='Total Confirmed cases', y='Name of State / UT', data=df)
plt.title('Total Confirmed cases by State/UT')
plt.xlabel('Total Confirmed cases')
plt.ylabel('State/UT')
plt.show()

# Graph 3: Scatter plot for Latitude and Longitude
plt.figure(figsize=(10, 6))
plt.scatter(df['Longitude'], df['Latitude'])
plt.title('Scatter plot of Latitude and Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# Graph 4: Pie chart for Death distribution
plt.figure(figsize=(8, 8))
plt.pie(df['Death'], labels=df['Name of State / UT'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Death by State/UT')
plt.show()

# Graph 5: Stacked bar plot for New cases, New deaths, and New recovered
df[['New cases', 'New deaths', 'New recovered']].plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Stacked Bar Plot for New cases, New deaths, and New recovered')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# Graph 6: Line plot for Total tests conducted over time
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['total_tests'])
plt.title('Total tests conducted over time')
plt.xlabel('Date')
plt.ylabel('Total tests conducted')
plt.show()

# Graph 7: Box plot for Active cases
plt.figure(figsize=(8, 8))
sns.boxplot(df['active_cases'])
plt.title('Box Plot for Active cases')
plt.show()

# Graph 8: Histogram for Total recovered cases
plt.figure(figsize=(10, 6))
plt.hist(df['total_recovered'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram for Total recovered cases')
plt.xlabel('Total recovered cases')
plt.ylabel('Frequency')
plt.show()

# Graph 9: Area plot for Total Confirmed cases and Total recovered over time
df[['Total Confirmed cases', 'total_recovered']].plot(kind='area', stacked=False, figsize=(12, 8))
plt.title('Area Plot for Total Confirmed cases and Total recovered over time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# Graph 10: Violin plot for Death distribution
plt.figure(figsize=(12, 8))
sns.violinplot(x='Death', y='Name of State / UT', data=df)
plt.title('Violin Plot for Death distribution by State/UT')
plt.xlabel('Death')
plt.ylabel('State/UT')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 35
#      33 # Graph 4: Pie chart for Death distribution
#      34 plt.figure(figsize=(8, 8))
# ---> 35 plt.pie(df['Death'], labels=df['Name of State / UT'], autopct='%1.1f%%', startangle=140)
#      36 plt.title('Distribution of Death by State/UT')
#      37 plt.show()
#
# File C:\Python\lib\site-packages\matplotlib\pyplot.py:2756, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2749 @_copy_docstring_and_deprecators(Axes.pie)
#    2750 def pie(
#    2751         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame df with the specified columns
# Example DataFrame:
# df = ...

# Sort the DataFrame by Total Confirmed cases in descending order
df_sorted = df.sort_values(by='Total Confirmed cases', ascending=False)

# Select the top 5 states
top_5_states = df_sorted.head(200)

# Bar plot for the top 5 states with highest total confirmed cases
plt.figure(figsize=(12, 8))
sns.barplot(x='Total Confirmed cases', y='Name of State / UT', data=top_5_states)
plt.title('Top 5 States with Highest Total Confirmed Cases')
plt.xlabel('Total Confirmed Cases')
plt.ylabel('State/UT')
plt.show()
